# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, color='green', linewidth=2, linestyle='--')  # Linha verde com traços
plt.title("Gráfico Personalizado")
plt.xlabel("Dias")
plt.ylabel("Valores")
plt.grid(True)  # Adiciona uma grade
plt.show()

# %%
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

print("All modules imported successfully")

# Configuração da API AIMLAPI
API_KEY = "83a2fe126d3544bfa12cda1f9a73352b"
API_URL = "https://api.aimlapi.com/biodiversity"

def get_biodiversity_data(city):
    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    }
    params = {"city": city}
    response = requests.get(API_URL, headers=headers, params=params)
    return response.json()

# Exemplo de uso
city = "Apiaí"
biodiversity_data = get_biodiversity_data(city)

print("Dados recebidos da API:")
print(biodiversity_data)

# Criar um gráfico simples para testar
plt.figure(figsize=(10, 6))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Gráfico de Teste")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

print("Script executed successfully")
# Out:
# All modules imported successfully
# Dados recebidos da API:
# {'requestId': '7d096b45-22fe-45c7-9d9b-a3a23c8768d5', 'statusCode': 404, 'timestamp': '2024-10-02T20:02:49.657Z', 'path': '/biodiversity?city=Apia%C3%AD', 'message': 'Cannot GET /biodiversity?city=Apia%C3%AD'}
# Script executed successfully

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y, color='green', linewidth=2, linestyle='--')  # Linha verde com traços
plt.title("Gráfico Personalizado")
plt.xlabel("Dias")
plt.ylabel("Valores")
plt.grid(True)  # Adiciona uma grade
plt.show()

# %%
import requests

# API configuration
API_KEY = "83a2fe126d3544bfa12cda1f9a73352b"
API_URL = "https://api.aimlapi.com/api/v1/chat/completions"

def query_ai(prompt):
    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    }
    
    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user", "content": prompt}]
    }
    
    try:
        response = requests.post(API_URL, json=data, headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes
        return response.json()['choices'][0]['message']['content']
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

print("Welcome to the AI Chat Interface!")
print("Type 'quit' to exit the program.")

while True:
    user_input = input("\nYou: ")
    
    if user_input.lower() == 'quit':
        print("Goodbye!")
        break
    
    response = query_ai(user_input)
    print(f"\nAI: {response}")
# Out:
# Welcome to the AI Chat Interface!
# Type 'quit' to exit the program.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 29
#      26 print("Type 'quit' to exit the program.")
#      28 while True:
# ---> 29     user_input = input("\nYou: ")
#      31     if user_input.lower() == 'quit':
#      32         print("Goodbye!")
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# ...
